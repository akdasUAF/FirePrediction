# %%
# !mkdir 0.Results_WeatherWildfireModel_PrepareDataSet

# %%
# !mkdir 1.Results_WeatherWildfireModel_BuildMLModels

# %%
# !mkdir 2.Resuts_WeatherWildfireModel_BuildDNNModels

# %%
# !mkdir 3.Results_WeatherWildfireModel_BuildZeroShotModel

# %%
# !mkdir 4.Results_WeatherModel_PrepareDataSet

# %%
# !mkdir 5.Results_WeatherModel_BuildMLModels
